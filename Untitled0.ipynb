# %%
# !pip install dfply
# Out:
# ...
#      |████████████████████████████████| 614kB 2.8MB/s
# ...

# %%
from dfply import *
import pandas as pd
csv = '/content/convertcsv.csv'
names=['id','number','bday','name','residence','owner','family']
df = pd.read_csv(csv,sep=',',names=names,index_col=False,header=None,skiprows=1)

# %%
df
# Out:
#                             id  ...                                          family
# 0     5d43f235be636905700bdbec  ...                                             NaN
# 1     5d43f235be636905700bdbf0  ...                                             NaN
# 2     5d43f235be636905700bdbf8  ...                                             NaN
# 3     5d43f235be636905700bdbf7  ...                              сестра Бел - София
# 4     5d43f235be636905700bdbfd  ...                                             NaN
# ...                        ...  ...                                             ...
# 1477  5d43f237be636905700be197  ...                                             NaN
# 1478  5d43f237be636905700be19d  ...                "поколение Ариа и Спарки - София
# 1479  5d43f237be636905700be1a1  ...   Дани Траянова Алексова и Екатерина Радукова "
# 1480  5d43f237be636905700be1a4  ...                                             NaN
# ...

# %%
(df >>
 ungroup(X.residence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-f70066cdc0a9> in <module>()
#       1 (df >>
# ----> 2  ungroup(X.residence))
#
# /usr/local/lib/python3.6/dist-packages/dfply/base.py in __rrshift__(self, other)
#     140             other_copy._grouped_by = getattr(other, '_grouped_by', None)
#     141
# --> 142         result = self.function(other_copy)
#     143
#     144         for p in self.chained_pipes:
#
# /usr/local/lib/python3.6/dist-packages/dfply/base.py in <lambda>(x)
#     147
#     148     def __call__(self, *args, **kwargs):
# --> 149         return pipe(lambda x: self.function(x, *args, **kwargs))
#     150
#     151
#
# TypeError: ungroup() takes 1 positional argument but 2 were given

# %%
df
# Out:
#                             id  ...                                          family
# 0     5d43f235be636905700bdbec  ...                                             NaN
# 1     5d43f235be636905700bdbf0  ...                                             NaN
# 2     5d43f235be636905700bdbf8  ...                                             NaN
# 3     5d43f235be636905700bdbf7  ...                              сестра Бел - София
# 4     5d43f235be636905700bdbfd  ...                                             NaN
# ...                        ...  ...                                             ...
# 1477  5d43f237be636905700be197  ...                                             NaN
# 1478  5d43f237be636905700be19d  ...                "поколение Ариа и Спарки - София
# 1479  5d43f237be636905700be1a1  ...   Дани Траянова Алексова и Екатерина Радукова "
# 1480  5d43f237be636905700be1a4  ...                                             NaN
# ...
