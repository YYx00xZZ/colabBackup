# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd Books
# Out:
# /content/gdrive/My Drive/Books

# %%
ls
# Out:
# 'book (1).pdf'                       express-handbook.pdf   react-handbook.pdf
#  book.pdf                            html-handbook.pdf     'Vue Handbook.pdf'
#  container-training-2019-pycon.pdf   node-handbook.pdf      WarDrive.zip

# %%
cd ..
# Out:
# /content/gdrive/My Drive

# %%
# !zip -r Books.zip Books/
# Out:
#   adding: Books/ (stored 0%)
#   adding: Books/html-handbook.pdf (deflated 23%)
#   adding: Books/Vue Handbook.pdf (deflated 14%)
#   adding: Books/express-handbook.pdf (deflated 20%)
#   adding: Books/node-handbook.pdf (deflated 23%)
#   adding: Books/react-handbook.pdf (deflated 23%)
#   adding: Books/book.pdf (deflated 29%)
#   adding: Books/book (1).pdf (deflated 1%)
#   adding: Books/container-training-2019-pycon.pdf (deflated 24%)
#   adding: Books/WarDrive.zip (stored 0%)

# %%
# !unzip WarDrive.zip -d ./wardrive
# Out:
# Archive:  WarDrive.zip
#   inflating: ./wardrive/DBtoCSV_Jun19.csv
#   inflating: ./wardrive/till16june/grumrun.kml
#   inflating: ./wardrive/till16june/26052020run
#   inflating: ./wardrive/till16june/wardrive.ipynb
#   inflating: ./wardrive/till16june/GrumRun(1).kml
#   inflating: ./wardrive/WiGLE-wholeDB.csv
#   inflating: ./wardrive/till16june/WiGLE KML Export.kml
#   inflating: ./wardrive/WiGLE KML Export.kml
#   inflating: ./wardrive/till16june/fullDb
#   inflating: ./wardrive/till16june/kmlFullDbLAST.kml
#   inflating: ./wardrive/till16june/kml28052020.kml
#   inflating: ./wardrive/till16june/runMalkoTaxi.kml
#   inflating: ./wardrive/till16june/forgearth.kml

# %%
cd /content/gdrive/My Drive
# Out:
# /content/gdrive/My Drive

# %%
ls
# Out:
# 'Colab Notebooks'/   IKN-1Kurs.zip           obdII/          Snimki/
#  DEV/               'KMSpico Portable.zip'   Officiary/      WarDrive.zip
#  go-pro-rap/         Mashup/                 ruter_backup/
