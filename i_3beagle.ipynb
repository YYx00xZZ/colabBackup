# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/assets/enriched_Beagle-Register.csv')

# %%
df['residence'].unique()
# Out:
# array(['София', 'Варна', 'Велико Търново', 'Плевен', 'Стара Загора',
#        'Шумен', 'Етрополе', 'Ямбол', 'Свищов', 'Пловдив', 'Козлодуй',
#        'Бургас', 'Видин', 'Враца', 'Пазарджик', 'Горна Оряховица', 'Русе',
#        'Перник', 'Ботевград', 'Монтана', 'Радомир', 'Нова Загора',
#        'Кюстендил', 'Априлово/София', 'Годеч', 'Хага - Холандия',
#        'Севлиево', 'Мюнстер, Германия', 'Берковица', 'Казанлък', 'Добрич',
#        'Димитровград', 'Белград - Сърбия', 'Благоевград',
#        'с. Слащен/Благоевград', 'Нови Искър', 'Смолян', 'Нови Пазар',
#        'Айтос', 'Дания', 'Хасково', 'Силистра', 'Лондон', 'Габрово',
#        'Самоков', 'Ловеч', 'Елин Пелин', 'гр. Раковски', 'Рудозем',
#        'Бойчиновци', 'Аксаково', 'Труд-Пловдие', 'Сливен',
#        'Копенхаген, Дания', 'Свиленград', 'Марково/Пловдив', 'Банкя',
#        'Англия', 'Монтпелие, Франция', 'Дюлево,Бургас', 'Каварна',
#        'Панагюрище', 'Несебър', 'Кърджали', 'Вълчедръм', 'Банско',
# ...

# %%
df['oblastniGradove'] = df['residence']

# %%
df.head()
# Out:
#          bday           name residence  ... isDead          diedOn oblastniGradove
# 0  2012-01-01           Беба     София  ...   True      15,3,2017,           София
# 1  2013-01-01           Лъки     Варна  ...  False  No information           Варна
# 2  2013-01-01  Biggie Smalls     София  ...  False  No information           София
# 3  2015-01-01           Биги     София  ...      0               0           София
# 4  2016-01-01          Дъсти     София  ...  False  No information           София
#
# [5 rows x 8 columns]

# %%
df[df['oblastniGradove'] == 'Роман']
# Out:
# Empty DataFrame
# Columns: [bday, name, residence, owner, family, isDead, diedOn, oblastniGradove]
# Index: []

# %%
df.at[1188, 'oblastniGradove'] = 'Враца'

# %%
len(df['oblastniGradove'].unique())
# Out:
# 148

# %%
df.to_csv('add_oblastniGradove.csv',sep=',',index=False)

# %% [markdown]
# do grad gabrovo
